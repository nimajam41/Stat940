# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/stat940project')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
import os
import numpy as np
import random
import math
import torch.optim as optim
from tqdm.auto import tqdm, trange

# %%
from dataset import load_data, save_data, load_targets, AdversarialDataset, load_adv_data
from utils.augmentations import *
from utils.utils import run, set_seed, pcshow
from models import Pointnet, DGCNN
from attacks import FGM, IFGM

# %%
set_seed(1)

# %%
parent_dir = '/content/drive/MyDrive/stat940project'
data_path = os.path.join(parent_dir, 'data/ModelNet40')

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    print('running on GPU')

else:
    device = torch.device('cpu')
    print('running on CPU')

test_X, test_y = load_data(data_path, mode='test')
test_targets = load_targets(data_path)
# Out:
# running on GPU

# %%
default_transforms = transforms.Compose(
    [
        ToTensor()
    ]
)

# %%
testset = AdversarialDataset(test_X, test_y, test_targets, transforms=default_transforms)
testloader = DataLoader(testset, batch_size=64, shuffle=False)

# %%
def run(targeted, file_name, output_path, model_name, signed = False):
      if model_name == "pointnet":
          model = Pointnet(device=device).to(device)
      else:
          model = DGCNN().to(device)
      checkpoint_path = os.path.join(parent_dir, f'checkpoints/{model_name}/best.pt')


      model.load_state_dict(torch.load(checkpoint_path, map_location=device)["model_state_dict"])
      model.eval()

      all_adv_pc = []
      all_gt_labels = []
      all_target_labels = []
      all_success = 0

      attacker = IFGM(model, epsilon=0.2, iterations=10)
      for pc, labels, targets in tqdm(testloader):
          with torch.no_grad():
              pc = pc.to(device)
              labels = labels.to(device)
              targets = targets.to(device)

          if targeted:
              adv_pc, success_num = attacker.attack(pc, targets, device, targeted=targeted)
          else:
              adv_pc, success_num = attacker.attack(pc, labels, device, targeted=targeted)

          all_adv_pc += [adv_pc]
          all_gt_labels += [labels.detach().cpu().numpy()]
          all_target_labels += [targets.detach().cpu().numpy()]
          all_success += success_num
          print()

      print(f"Success Rate: {all_success / len(test_X)}")


      all_adv_pc = np.concatenate(all_adv_pc, axis=0)
      all_gt_labels = np.concatenate(all_gt_labels, axis=0)
      all_target_labels = np.concatenate(all_target_labels, axis=0)



      save_data(all_adv_pc, file_name, output_path)
      save_data(all_gt_labels, 'test_labels', output_path)
      save_data(all_adv_pc, 'target_labels', output_path)
      return all_adv_pc

# %%
path = os.path.join(parent_dir, 'data/IFGM/Pointnet')
if not os.path.exists(path):
    os.makedirs(path)
all_adv_pc = run(False, 'adv_test_untarget', path, 'pointnet', signed = False)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# 14/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 25/64 successful attacks in iteration  2
# 30/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 35/64 successful attacks in iteration  5
# 38/64 successful attacks in iteration  6
# 42/64 successful attacks in iteration  7
# 46/64 successful attacks in iteration  8
# 48/64 successful attacks in iteration  9
# 48/64 Total successful attacks
#
# 12/64 successful attacks in iteration  0
# 15/64 successful attacks in iteration  1
# 19/64 successful attacks in iteration  2
# 23/64 successful attacks in iteration  3
# 28/64 successful attacks in iteration  4
# 30/64 successful attacks in iteration  5
# 32/64 successful attacks in iteration  6
# 36/64 successful attacks in iteration  7
# 40/64 successful attacks in iteration  8
# 40/64 successful attacks in iteration  9
# 42/64 Total successful attacks
#
# 13/64 successful attacks in iteration  0
# 14/64 successful attacks in iteration  1
# 21/64 successful attacks in iteration  2
# 24/64 successful attacks in iteration  3
# 28/64 successful attacks in iteration  4
# 35/64 successful attacks in iteration  5
# 40/64 successful attacks in iteration  6
# 42/64 successful attacks in iteration  7
# 44/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 47/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 22/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 35/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 41/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 49/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 23/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 33/64 successful attacks in iteration  5
# 39/64 successful attacks in iteration  6
# 43/64 successful attacks in iteration  7
# 45/64 successful attacks in iteration  8
# 47/64 successful attacks in iteration  9
# 51/64 Total successful attacks
#
# 19/64 successful attacks in iteration  0
# 21/64 successful attacks in iteration  1
# 26/64 successful attacks in iteration  2
# 29/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 35/64 successful attacks in iteration  5
# 38/64 successful attacks in iteration  6
# 44/64 successful attacks in iteration  7
# 46/64 successful attacks in iteration  8
# 47/64 successful attacks in iteration  9
# 48/64 Total successful attacks
#
# 21/64 successful attacks in iteration  0
# 21/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 30/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 36/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 38/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 43/64 successful attacks in iteration  9
# 46/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 17/64 successful attacks in iteration  1
# 21/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 31/64 successful attacks in iteration  4
# 37/64 successful attacks in iteration  5
# 41/64 successful attacks in iteration  6
# 44/64 successful attacks in iteration  7
# 45/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 47/64 Total successful attacks
#
# 17/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 23/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 29/64 successful attacks in iteration  4
# 33/64 successful attacks in iteration  5
# 40/64 successful attacks in iteration  6
# 44/64 successful attacks in iteration  7
# 47/64 successful attacks in iteration  8
# 49/64 successful attacks in iteration  9
# 52/64 Total successful attacks
#
# 12/64 successful attacks in iteration  0
# 15/64 successful attacks in iteration  1
# 19/64 successful attacks in iteration  2
# 21/64 successful attacks in iteration  3
# 26/64 successful attacks in iteration  4
# 31/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 41/64 successful attacks in iteration  7
# 44/64 successful attacks in iteration  8
# 47/64 successful attacks in iteration  9
# 53/64 Total successful attacks
#
# 17/64 successful attacks in iteration  0
# 19/64 successful attacks in iteration  1
# 22/64 successful attacks in iteration  2
# 28/64 successful attacks in iteration  3
# 35/64 successful attacks in iteration  4
# 37/64 successful attacks in iteration  5
# 42/64 successful attacks in iteration  6
# 46/64 successful attacks in iteration  7
# 48/64 successful attacks in iteration  8
# 51/64 successful attacks in iteration  9
# 54/64 Total successful attacks
#
# 17/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 28/64 successful attacks in iteration  3
# 30/64 successful attacks in iteration  4
# 31/64 successful attacks in iteration  5
# 38/64 successful attacks in iteration  6
# 41/64 successful attacks in iteration  7
# 41/64 successful attacks in iteration  8
# 44/64 successful attacks in iteration  9
# 47/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 16/64 successful attacks in iteration  1
# 22/64 successful attacks in iteration  2
# 26/64 successful attacks in iteration  3
# 34/64 successful attacks in iteration  4
# 36/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 43/64 successful attacks in iteration  7
# 48/64 successful attacks in iteration  8
# 50/64 successful attacks in iteration  9
# 50/64 Total successful attacks
#
# 16/64 successful attacks in iteration  0
# 18/64 successful attacks in iteration  1
# 22/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 31/64 successful attacks in iteration  4
# 34/64 successful attacks in iteration  5
# 39/64 successful attacks in iteration  6
# 40/64 successful attacks in iteration  7
# 46/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 48/64 Total successful attacks
#
# 9/64 successful attacks in iteration  0
# 13/64 successful attacks in iteration  1
# 17/64 successful attacks in iteration  2
# 19/64 successful attacks in iteration  3
# 23/64 successful attacks in iteration  4
# 25/64 successful attacks in iteration  5
# 32/64 successful attacks in iteration  6
# 36/64 successful attacks in iteration  7
# 40/64 successful attacks in iteration  8
# 42/64 successful attacks in iteration  9
# 44/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 19/64 successful attacks in iteration  1
# 23/64 successful attacks in iteration  2
# 26/64 successful attacks in iteration  3
# 29/64 successful attacks in iteration  4
# 32/64 successful attacks in iteration  5
# 33/64 successful attacks in iteration  6
# 36/64 successful attacks in iteration  7
# 40/64 successful attacks in iteration  8
# 41/64 successful attacks in iteration  9
# 44/64 Total successful attacks
#
# 17/64 successful attacks in iteration  0
# 19/64 successful attacks in iteration  1
# 27/64 successful attacks in iteration  2
# 28/64 successful attacks in iteration  3
# 30/64 successful attacks in iteration  4
# 33/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 43/64 successful attacks in iteration  7
# 48/64 successful attacks in iteration  8
# 52/64 successful attacks in iteration  9
# 56/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 16/64 successful attacks in iteration  1
# 18/64 successful attacks in iteration  2
# 24/64 successful attacks in iteration  3
# 26/64 successful attacks in iteration  4
# 31/64 successful attacks in iteration  5
# 34/64 successful attacks in iteration  6
# 37/64 successful attacks in iteration  7
# 42/64 successful attacks in iteration  8
# 45/64 successful attacks in iteration  9
# 50/64 Total successful attacks
#
# 18/64 successful attacks in iteration  0
# 22/64 successful attacks in iteration  1
# 26/64 successful attacks in iteration  2
# 28/64 successful attacks in iteration  3
# 33/64 successful attacks in iteration  4
# 37/64 successful attacks in iteration  5
# 38/64 successful attacks in iteration  6
# 41/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 49/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 16/64 successful attacks in iteration  1
# 18/64 successful attacks in iteration  2
# 22/64 successful attacks in iteration  3
# 29/64 successful attacks in iteration  4
# 33/64 successful attacks in iteration  5
# 40/64 successful attacks in iteration  6
# 42/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 49/64 successful attacks in iteration  9
# 51/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 18/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 29/64 successful attacks in iteration  3
# 36/64 successful attacks in iteration  4
# 40/64 successful attacks in iteration  5
# 42/64 successful attacks in iteration  6
# 42/64 successful attacks in iteration  7
# 44/64 successful attacks in iteration  8
# 44/64 successful attacks in iteration  9
# 48/64 Total successful attacks
#
# 18/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 29/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 38/64 successful attacks in iteration  5
# 38/64 successful attacks in iteration  6
# 43/64 successful attacks in iteration  7
# 48/64 successful attacks in iteration  8
# 49/64 successful attacks in iteration  9
# 51/64 Total successful attacks
#
# 9/64 successful attacks in iteration  0
# 14/64 successful attacks in iteration  1
# 17/64 successful attacks in iteration  2
# 22/64 successful attacks in iteration  3
# 29/64 successful attacks in iteration  4
# 33/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 39/64 successful attacks in iteration  7
# 41/64 successful attacks in iteration  8
# 43/64 successful attacks in iteration  9
# 44/64 Total successful attacks
#
# 17/64 successful attacks in iteration  0
# 21/64 successful attacks in iteration  1
# 23/64 successful attacks in iteration  2
# 25/64 successful attacks in iteration  3
# 29/64 successful attacks in iteration  4
# 32/64 successful attacks in iteration  5
# 33/64 successful attacks in iteration  6
# 34/64 successful attacks in iteration  7
# 40/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 50/64 Total successful attacks
#
# 9/64 successful attacks in iteration  0
# 12/64 successful attacks in iteration  1
# 16/64 successful attacks in iteration  2
# 18/64 successful attacks in iteration  3
# 21/64 successful attacks in iteration  4
# 24/64 successful attacks in iteration  5
# 30/64 successful attacks in iteration  6
# 33/64 successful attacks in iteration  7
# 36/64 successful attacks in iteration  8
# 39/64 successful attacks in iteration  9
# 42/64 Total successful attacks
#
# 14/64 successful attacks in iteration  0
# 19/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 29/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 38/64 successful attacks in iteration  5
# 42/64 successful attacks in iteration  6
# 44/64 successful attacks in iteration  7
# 46/64 successful attacks in iteration  8
# 50/64 successful attacks in iteration  9
# 50/64 Total successful attacks
#
# 15/64 successful attacks in iteration  0
# 17/64 successful attacks in iteration  1
# 23/64 successful attacks in iteration  2
# 34/64 successful attacks in iteration  3
# 36/64 successful attacks in iteration  4
# 39/64 successful attacks in iteration  5
# 42/64 successful attacks in iteration  6
# 44/64 successful attacks in iteration  7
# 47/64 successful attacks in iteration  8
# 47/64 successful attacks in iteration  9
# 47/64 Total successful attacks
#
# 11/64 successful attacks in iteration  0
# 17/64 successful attacks in iteration  1
# 20/64 successful attacks in iteration  2
# 25/64 successful attacks in iteration  3
# 27/64 successful attacks in iteration  4
# 29/64 successful attacks in iteration  5
# 35/64 successful attacks in iteration  6
# 41/64 successful attacks in iteration  7
# 42/64 successful attacks in iteration  8
# 44/64 successful attacks in iteration  9
# 46/64 Total successful attacks
#
# 13/64 successful attacks in iteration  0
# 14/64 successful attacks in iteration  1
# 17/64 successful attacks in iteration  2
# 21/64 successful attacks in iteration  3
# 25/64 successful attacks in iteration  4
# 28/64 successful attacks in iteration  5
# 33/64 successful attacks in iteration  6
# 37/64 successful attacks in iteration  7
# 39/64 successful attacks in iteration  8
# 42/64 successful attacks in iteration  9
# 43/64 Total successful attacks
#
# 16/64 successful attacks in iteration  0
# 22/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 31/64 successful attacks in iteration  3
# 36/64 successful attacks in iteration  4
# 40/64 successful attacks in iteration  5
# 43/64 successful attacks in iteration  6
# 45/64 successful attacks in iteration  7
# 47/64 successful attacks in iteration  8
# 48/64 successful attacks in iteration  9
# 49/64 Total successful attacks
#
# 18/64 successful attacks in iteration  0
# 20/64 successful attacks in iteration  1
# 23/64 successful attacks in iteration  2
# 23/64 successful attacks in iteration  3
# 26/64 successful attacks in iteration  4
# 29/64 successful attacks in iteration  5
# 33/64 successful attacks in iteration  6
# 38/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 47/64 Total successful attacks
#
# 17/64 successful attacks in iteration  0
# 19/64 successful attacks in iteration  1
# 26/64 successful attacks in iteration  2
# 29/64 successful attacks in iteration  3
# 30/64 successful attacks in iteration  4
# 34/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 38/64 successful attacks in iteration  7
# 41/64 successful attacks in iteration  8
# 44/64 successful attacks in iteration  9
# 45/64 Total successful attacks
#
# 10/64 successful attacks in iteration  0
# 15/64 successful attacks in iteration  1
# 21/64 successful attacks in iteration  2
# 25/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 38/64 successful attacks in iteration  5
# 42/64 successful attacks in iteration  6
# 45/64 successful attacks in iteration  7
# 48/64 successful attacks in iteration  8
# 52/64 successful attacks in iteration  9
# 54/64 Total successful attacks
#
# 20/64 successful attacks in iteration  0
# 24/64 successful attacks in iteration  1
# 26/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 31/64 successful attacks in iteration  4
# 36/64 successful attacks in iteration  5
# 40/64 successful attacks in iteration  6
# 44/64 successful attacks in iteration  7
# 49/64 successful attacks in iteration  8
# 49/64 successful attacks in iteration  9
# 50/64 Total successful attacks
#
# 15/64 successful attacks in iteration  0
# 19/64 successful attacks in iteration  1
# 24/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 29/64 successful attacks in iteration  4
# 30/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 39/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 46/64 successful attacks in iteration  9
# 49/64 Total successful attacks
#
# 13/64 successful attacks in iteration  0
# 17/64 successful attacks in iteration  1
# 20/64 successful attacks in iteration  2
# 20/64 successful attacks in iteration  3
# 26/64 successful attacks in iteration  4
# 31/64 successful attacks in iteration  5
# 38/64 successful attacks in iteration  6
# 42/64 successful attacks in iteration  7
# 44/64 successful attacks in iteration  8
# 48/64 successful attacks in iteration  9
# 52/64 Total successful attacks
#
# 13/64 successful attacks in iteration  0
# 14/64 successful attacks in iteration  1
# 20/64 successful attacks in iteration  2
# 27/64 successful attacks in iteration  3
# 32/64 successful attacks in iteration  4
# 36/64 successful attacks in iteration  5
# 40/64 successful attacks in iteration  6
# 43/64 successful attacks in iteration  7
# 43/64 successful attacks in iteration  8
# 47/64 successful attacks in iteration  9
# 49/64 Total successful attacks
#
# 12/64 successful attacks in iteration  0
# 13/64 successful attacks in iteration  1
# 21/64 successful attacks in iteration  2
# 23/64 successful attacks in iteration  3
# 28/64 successful attacks in iteration  4
# 34/64 successful attacks in iteration  5
# 37/64 successful attacks in iteration  6
# 38/64 successful attacks in iteration  7
# 41/64 successful attacks in iteration  8
# 45/64 successful attacks in iteration  9
# 46/64 Total successful attacks
#
# 7/36 successful attacks in iteration  0
# 8/36 successful attacks in iteration  1
# 10/36 successful attacks in iteration  2
# 12/36 successful attacks in iteration  3
# 13/36 successful attacks in iteration  4
# 15/36 successful attacks in iteration  5
# 17/36 successful attacks in iteration  6
# 19/36 successful attacks in iteration  7
# 23/36 successful attacks in iteration  8
# 24/36 successful attacks in iteration  9
# 25/36 Total successful attacks
#
# Success Rate: 0.7548622366288493

# %%
x1, y1, z1 = all_adv_pc[1].T
x2, y2, z2 = test_X[1].T
pcshow(x1, y1, z1, color='red')
pcshow(x2, y2, z2, color='blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d787869a-d173-4a54-bbab-a09073956b0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d787869a-d173-4a54-bbab-a09073956b0c")) {                    Plotly.newPlot(                        "d787869a-d173-4a54-bbab-a09073956b0c",                        [{"mode":"markers","x":[0.5078481435775757,-0.47557130455970764,0.2196892499923706,0.2926334738731384,-0.7602033615112305,-0.4532950818538666,-0.8045063018798828,0.3154626488685608,0.6901146769523621,-0.32264697551727295,0.5734501481056213,0.1984456181526184,-0.5577251315116882,-0.48544639
# %%
path = os.path.join(parent_dir, 'data/IFGM/Pointnet')
all_adv_pc = run(True, 'adv_test_target', path, 'pointnet', signed = False)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 6/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 4/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 7/64 successful attacks in iteration  9
# 7/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 4/64 successful attacks in iteration  6
# 5/64 successful attacks in iteration  7
# 6/64 successful attacks in iteration  8
# 6/64 successful attacks in iteration  9
# 6/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 3/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 3/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 5/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 7/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 2/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 2/64 successful attacks in iteration  0
# 2/64 successful attacks in iteration  1
# 2/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 3/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 4/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 5/64 successful attacks in iteration  9
# 6/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 2/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 2/64 successful attacks in iteration  0
# 2/64 successful attacks in iteration  1
# 2/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 4/64 successful attacks in iteration  4
# 4/64 successful attacks in iteration  5
# 4/64 successful attacks in iteration  6
# 5/64 successful attacks in iteration  7
# 5/64 successful attacks in iteration  8
# 6/64 successful attacks in iteration  9
# 7/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 5/64 successful attacks in iteration  9
# 6/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 2/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 2/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 3/64 successful attacks in iteration  4
# 3/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 4/64 successful attacks in iteration  7
# 5/64 successful attacks in iteration  8
# 6/64 successful attacks in iteration  9
# 8/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 6/64 successful attacks in iteration  9
# 7/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 3/64 successful attacks in iteration  4
# 5/64 successful attacks in iteration  5
# 6/64 successful attacks in iteration  6
# 8/64 successful attacks in iteration  7
# 8/64 successful attacks in iteration  8
# 9/64 successful attacks in iteration  9
# 9/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 5/64 successful attacks in iteration  8
# 5/64 successful attacks in iteration  9
# 6/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 4/64 successful attacks in iteration  8
# 4/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 6/64 successful attacks in iteration  7
# 7/64 successful attacks in iteration  8
# 8/64 successful attacks in iteration  9
# 10/64 Total successful attacks
#
# 0/36 successful attacks in iteration  0
# 0/36 successful attacks in iteration  1
224569261074066,-0.09085746109485626,-0.2885931432247162,-0.19409653544425964,0.17758402228355408,0.25851428508758545,0.15551972389221191,0.13818883895874023,0.1208692342042923,-0.328249990940094,-0.25424444675445557,-0.05440737307071686,0.18904107809066772,-0.2696659564971924,0.019256174564361572,-0.2019575536251068,0.25027772784233093,-0.29791927337646484,-0.35335808992385864,0.28673502802848816,-0.3482399880886078,-0.2825131118297577,0.14924395084381104,0.11889152973890305,-0.16421180963516235,0.1953536570072174,0.14030669629573822,0.19538670778274536,-0.2892311215400696,-0.042710140347480774,-0.1925797015428543,0.29328665137290955,0.14897148311138153,0.004605010151863098,-0.25793203711509705,0.27528566122055054,0.31723305583000183,0.33593490719795227,0.31235772371292114,-0.21481862664222717,0.06305237114429474,0.25571519136428833,0.11889153718948364,-0.2969444990158081,0.12436126172542572,0.1398037225008011,-0.22388237714767456,-0.020560935139656067,-0.25424444675445557,0.250973641872406,0.10029155015945435,0.26726579666137695,0.29120388627052307,-0.27584779262542725,-0.35335811972618103,0.12553498148918152,-0.03250493109226227,0.3533996045589447,0.25571519136428833,0.032013535499572754,-0.31632885336875916,0.2800690233707428,0.35 ...

# %%
path = os.path.join(parent_dir, 'data/IFGM/DGCNN')
if not os.path.exists(path):
    os.makedirs(path)
all_adv_pc = run(False, 'adv_test_untarget', path, 'dgcnn', signed = False)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# 6/64 successful attacks in iteration  0
# 8/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 10/64 successful attacks in iteration  3
# 12/64 successful attacks in iteration  4
# 13/64 successful attacks in iteration  5
# 16/64 successful attacks in iteration  6
# 17/64 successful attacks in iteration  7
# 20/64 successful attacks in iteration  8
# 21/64 successful attacks in iteration  9
# 23/64 Total successful attacks
#
# 4/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 11/64 successful attacks in iteration  4
# 13/64 successful attacks in iteration  5
# 15/64 successful attacks in iteration  6
# 17/64 successful attacks in iteration  7
# 20/64 successful attacks in iteration  8
# 21/64 successful attacks in iteration  9
# 23/64 Total successful attacks
#
# 4/64 successful attacks in iteration  0
# 4/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 10/64 successful attacks in iteration  4
# 11/64 successful attacks in iteration  5
# 13/64 successful attacks in iteration  6
# 15/64 successful attacks in iteration  7
# 16/64 successful attacks in iteration  8
# 19/64 successful attacks in iteration  9
# 22/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 9/64 successful attacks in iteration  1
# 11/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 12/64 successful attacks in iteration  4
# 14/64 successful attacks in iteration  5
# 18/64 successful attacks in iteration  6
# 22/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 26/64 successful attacks in iteration  9
# 27/64 Total successful attacks
#
# 8/64 successful attacks in iteration  0
# 9/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 10/64 successful attacks in iteration  3
# 13/64 successful attacks in iteration  4
# 15/64 successful attacks in iteration  5
# 18/64 successful attacks in iteration  6
# 19/64 successful attacks in iteration  7
# 24/64 successful attacks in iteration  8
# 27/64 successful attacks in iteration  9
# 30/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 10/64 successful attacks in iteration  1
# 14/64 successful attacks in iteration  2
# 16/64 successful attacks in iteration  3
# 18/64 successful attacks in iteration  4
# 21/64 successful attacks in iteration  5
# 21/64 successful attacks in iteration  6
# 23/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 27/64 successful attacks in iteration  9
# 28/64 Total successful attacks
#
# 5/64 successful attacks in iteration  0
# 7/64 successful attacks in iteration  1
# 8/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 9/64 successful attacks in iteration  4
# 12/64 successful attacks in iteration  5
# 14/64 successful attacks in iteration  6
# 16/64 successful attacks in iteration  7
# 20/64 successful attacks in iteration  8
# 20/64 successful attacks in iteration  9
# 26/64 Total successful attacks
#
# 4/64 successful attacks in iteration  0
# 5/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 13/64 successful attacks in iteration  4
# 14/64 successful attacks in iteration  5
# 16/64 successful attacks in iteration  6
# 18/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 25/64 successful attacks in iteration  9
# 27/64 Total successful attacks
#
# 5/64 successful attacks in iteration  0
# 7/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 8/64 successful attacks in iteration  4
# 10/64 successful attacks in iteration  5
# 13/64 successful attacks in iteration  6
# 15/64 successful attacks in iteration  7
# 14/64 successful attacks in iteration  8
# 18/64 successful attacks in iteration  9
# 17/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 7/64 successful attacks in iteration  1
# 11/64 successful attacks in iteration  2
# 12/64 successful attacks in iteration  3
# 15/64 successful attacks in iteration  4
# 17/64 successful attacks in iteration  5
# 20/64 successful attacks in iteration  6
# 24/64 successful attacks in iteration  7
# 28/64 successful attacks in iteration  8
# 30/64 successful attacks in iteration  9
# 33/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 14/64 successful attacks in iteration  4
# 14/64 successful attacks in iteration  5
# 15/64 successful attacks in iteration  6
# 17/64 successful attacks in iteration  7
# 18/64 successful attacks in iteration  8
# 22/64 successful attacks in iteration  9
# 23/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 9/64 successful attacks in iteration  1
# 10/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 11/64 successful attacks in iteration  4
# 13/64 successful attacks in iteration  5
# 14/64 successful attacks in iteration  6
# 15/64 successful attacks in iteration  7
# 16/64 successful attacks in iteration  8
# 19/64 successful attacks in iteration  9
# 20/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 9/64 successful attacks in iteration  1
# 11/64 successful attacks in iteration  2
# 15/64 successful attacks in iteration  3
# 18/64 successful attacks in iteration  4
# 18/64 successful attacks in iteration  5
# 19/64 successful attacks in iteration  6
# 19/64 successful attacks in iteration  7
# 21/64 successful attacks in iteration  8
# 23/64 successful attacks in iteration  9
# 25/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 8/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 10/64 successful attacks in iteration  4
# 13/64 successful attacks in iteration  5
# 13/64 successful attacks in iteration  6
# 17/64 successful attacks in iteration  7
# 18/64 successful attacks in iteration  8
# 20/64 successful attacks in iteration  9
# 25/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 8/64 successful attacks in iteration  3
# 10/64 successful attacks in iteration  4
# 12/64 successful attacks in iteration  5
# 17/64 successful attacks in iteration  6
# 19/64 successful attacks in iteration  7
# 20/64 successful attacks in iteration  8
# 21/64 successful attacks in iteration  9
# 23/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 7/64 successful attacks in iteration  1
# 10/64 successful attacks in iteration  2
# 13/64 successful attacks in iteration  3
# 15/64 successful attacks in iteration  4
# 17/64 successful attacks in iteration  5
# 16/64 successful attacks in iteration  6
# 22/64 successful attacks in iteration  7
# 24/64 successful attacks in iteration  8
# 24/64 successful attacks in iteration  9
# 23/64 Total successful attacks
#
# 12/64 successful attacks in iteration  0
# 14/64 successful attacks in iteration  1
# 14/64 successful attacks in iteration  2
# 21/64 successful attacks in iteration  3
# 22/64 successful attacks in iteration  4
# 20/64 successful attacks in iteration  5
# 26/64 successful attacks in iteration  6
# 25/64 successful attacks in iteration  7
# 30/64 successful attacks in iteration  8
# 30/64 successful attacks in iteration  9
# 32/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 8/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 14/64 successful attacks in iteration  4
# 13/64 successful attacks in iteration  5
# 13/64 successful attacks in iteration  6
# 16/64 successful attacks in iteration  7
# 19/64 successful attacks in iteration  8
# 23/64 successful attacks in iteration  9
# 26/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 10/64 successful attacks in iteration  1
# 14/64 successful attacks in iteration  2
# 14/64 successful attacks in iteration  3
# 17/64 successful attacks in iteration  4
# 17/64 successful attacks in iteration  5
# 21/64 successful attacks in iteration  6
# 22/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 27/64 successful attacks in iteration  9
# 30/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 8/64 successful attacks in iteration  1
# 8/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 13/64 successful attacks in iteration  4
# 18/64 successful attacks in iteration  5
# 20/64 successful attacks in iteration  6
# 21/64 successful attacks in iteration  7
# 24/64 successful attacks in iteration  8
# 25/64 successful attacks in iteration  9
# 26/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 6/64 successful attacks in iteration  2
# 7/64 successful attacks in iteration  3
# 7/64 successful attacks in iteration  4
# 10/64 successful attacks in iteration  5
# 11/64 successful attacks in iteration  6
# 14/64 successful attacks in iteration  7
# 17/64 successful attacks in iteration  8
# 22/64 successful attacks in iteration  9
# 26/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 8/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 11/64 successful attacks in iteration  4
# 12/64 successful attacks in iteration  5
# 16/64 successful attacks in iteration  6
# 15/64 successful attacks in iteration  7
# 16/64 successful attacks in iteration  8
# 16/64 successful attacks in iteration  9
# 22/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 4/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 8/64 successful attacks in iteration  4
# 10/64 successful attacks in iteration  5
# 14/64 successful attacks in iteration  6
# 16/64 successful attacks in iteration  7
# 15/64 successful attacks in iteration  8
# 17/64 successful attacks in iteration  9
# 18/64 Total successful attacks
#
# 4/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 9/64 successful attacks in iteration  3
# 12/64 successful attacks in iteration  4
# 12/64 successful attacks in iteration  5
# 13/64 successful attacks in iteration  6
# 17/64 successful attacks in iteration  7
# 19/64 successful attacks in iteration  8
# 19/64 successful attacks in iteration  9
# 19/64 Total successful attacks
#
# 5/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 8/64 successful attacks in iteration  2
# 8/64 successful attacks in iteration  3
# 12/64 successful attacks in iteration  4
# 13/64 successful attacks in iteration  5
# 14/64 successful attacks in iteration  6
# 17/64 successful attacks in iteration  7
# 18/64 successful attacks in iteration  8
# 20/64 successful attacks in iteration  9
# 24/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 5/64 successful attacks in iteration  1
# 5/64 successful attacks in iteration  2
# 5/64 successful attacks in iteration  3
# 6/64 successful attacks in iteration  4
# 8/64 successful attacks in iteration  5
# 9/64 successful attacks in iteration  6
# 11/64 successful attacks in iteration  7
# 14/64 successful attacks in iteration  8
# 16/64 successful attacks in iteration  9
# 19/64 Total successful attacks
#
# 5/64 successful attacks in iteration  0
# 5/64 successful attacks in iteration  1
# 7/64 successful attacks in iteration  2
# 10/64 successful attacks in iteration  3
# 10/64 successful attacks in iteration  4
# 11/64 successful attacks in iteration  5
# 11/64 successful attacks in iteration  6
# 16/64 successful attacks in iteration  7
# 18/64 successful attacks in iteration  8
# 19/64 successful attacks in iteration  9
# 24/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 10/64 successful attacks in iteration  1
# 13/64 successful attacks in iteration  2
# 16/64 successful attacks in iteration  3
# 17/64 successful attacks in iteration  4
# 19/64 successful attacks in iteration  5
# 20/64 successful attacks in iteration  6
# 21/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 25/64 successful attacks in iteration  9
# 27/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 7/64 successful attacks in iteration  1
# 9/64 successful attacks in iteration  2
# 12/64 successful attacks in iteration  3
# 13/64 successful attacks in iteration  4
# 15/64 successful attacks in iteration  5
# 14/64 successful attacks in iteration  6
# 18/64 successful attacks in iteration  7
# 19/64 successful attacks in iteration  8
# 24/64 successful attacks in iteration  9
# 24/64 Total successful attacks
#
# 9/64 successful attacks in iteration  0
# 13/64 successful attacks in iteration  1
# 13/64 successful attacks in iteration  2
# 16/64 successful attacks in iteration  3
# 19/64 successful attacks in iteration  4
# 23/64 successful attacks in iteration  5
# 25/64 successful attacks in iteration  6
# 27/64 successful attacks in iteration  7
# 29/64 successful attacks in iteration  8
# 31/64 successful attacks in iteration  9
# 30/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 8/64 successful attacks in iteration  1
# 10/64 successful attacks in iteration  2
# 12/64 successful attacks in iteration  3
# 12/64 successful attacks in iteration  4
# 17/64 successful attacks in iteration  5
# 16/64 successful attacks in iteration  6
# 16/64 successful attacks in iteration  7
# 18/64 successful attacks in iteration  8
# 22/64 successful attacks in iteration  9
# 24/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 10/64 successful attacks in iteration  1
# 10/64 successful attacks in iteration  2
# 13/64 successful attacks in iteration  3
# 15/64 successful attacks in iteration  4
# 16/64 successful attacks in iteration  5
# 18/64 successful attacks in iteration  6
# 20/64 successful attacks in iteration  7
# 22/64 successful attacks in iteration  8
# 23/64 successful attacks in iteration  9
# 27/64 Total successful attacks
#
# 4/64 successful attacks in iteration  0
# 6/64 successful attacks in iteration  1
# 8/64 successful attacks in iteration  2
# 8/64 successful attacks in iteration  3
# 11/64 successful attacks in iteration  4
# 14/64 successful attacks in iteration  5
# 17/64 successful attacks in iteration  6
# 18/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 25/64 successful attacks in iteration  9
# 26/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 3/64 successful attacks in iteration  1
# 5/64 successful attacks in iteration  2
# 6/64 successful attacks in iteration  3
# 8/64 successful attacks in iteration  4
# 14/64 successful attacks in iteration  5
# 17/64 successful attacks in iteration  6
# 20/64 successful attacks in iteration  7
# 20/64 successful attacks in iteration  8
# 24/64 successful attacks in iteration  9
# 26/64 Total successful attacks
#
# 6/64 successful attacks in iteration  0
# 8/64 successful attacks in iteration  1
# 12/64 successful attacks in iteration  2
# 15/64 successful attacks in iteration  3
# 16/64 successful attacks in iteration  4
# 19/64 successful attacks in iteration  5
# 22/64 successful attacks in iteration  6
# 22/64 successful attacks in iteration  7
# 26/64 successful attacks in iteration  8
# 32/64 successful attacks in iteration  9
# 34/64 Total successful attacks
#
# 3/64 successful attacks in iteration  0
# 4/64 successful attacks in iteration  1
# 5/64 successful attacks in iteration  2
# 6/64 successful attacks in iteration  3
# 8/64 successful attacks in iteration  4
# 11/64 successful attacks in iteration  5
# 11/64 successful attacks in iteration  6
# 15/64 successful attacks in iteration  7
# 17/64 successful attacks in iteration  8
# 18/64 successful attacks in iteration  9
# 20/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 7/64 successful attacks in iteration  1
# 8/64 successful attacks in iteration  2
# 12/64 successful attacks in iteration  3
# 15/64 successful attacks in iteration  4
# 15/64 successful attacks in iteration  5
# 20/64 successful attacks in iteration  6
# 23/64 successful attacks in iteration  7
# 23/64 successful attacks in iteration  8
# 27/64 successful attacks in iteration  9
# 30/64 Total successful attacks
#
# 7/64 successful attacks in iteration  0
# 10/64 successful attacks in iteration  1
# 10/64 successful attacks in iteration  2
# 11/64 successful attacks in iteration  3
# 11/64 successful attacks in iteration  4
# 14/64 successful attacks in iteration  5
# 19/64 successful attacks in iteration  6
# 20/64 successful attacks in iteration  7
# 21/64 successful attacks in iteration  8
# 26/64 successful attacks in iteration  9
# 29/64 Total successful attacks
#
# 2/36 successful attacks in iteration  0
# 2/36 successful attacks in iteration  1
# 2/36 successful attacks in iteration  2
# 3/36 successful attacks in iteration  3
# 4/36 successful attacks in iteration  4
# 8/36 successful attacks in iteration  5
# 10/36 successful attacks in iteration  6
# 9/36 successful attacks in iteration  7
# 11/36 successful attacks in iteration  8
# 12/36 successful attacks in iteration  9
# 15/36 Total successful attacks
#
# Success Rate: 0.3942463533225284

# %%
x1, y1, z1 = all_adv_pc[6].T
x2, y2, z2 = test_X[6].T
pcshow(x1, y1, z1, color='red')
pcshow(x2, y2, z2, color='blue')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6db9d8c6-bc6f-40a6-8e35-160f5a6bd44e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6db9d8c6-bc6f-40a6-8e35-160f5a6bd44e")) {                    Plotly.newPlot(                        "6db9d8c6-bc6f-40a6-8e35-160f5a6bd44e",                        [{"mode":"markers","x":[0.03014395758509636,0.3801839351654053,0.45268407464027405,0.1970086395740509,-0.4250428378582001,-0.2492254227399826,-0.21832187473773956,0.43328648805618286,-0.26662543416023254,-0.13226474821567535,-0.1132708340883255,0.4806100130081177,-0.07240158319473267,0.31427592039108276,0.09678788483142853,-0.44579240679740906,-0.4737895727157593,-0.29232120513916016,-0.12725967168807983,-0.37282902002334595,-0.08395392447710037,-0.21486298739910126,-0.1810024380683899,0.3312253952026367,0.4167475402355194,0.39425966143608093,0.2225077599287033,-0.2584545314311981,0.16976553201675415,-0.24054445326328278,-0.07694897800683975,-0.28812554478645325,-0.13491958379745483,-0.1399070769548416,-0.19314293563365936,-0.18187543749809265,0.2704923450946808,0.15701287984848022,-0.3011373281478882,0.4352847635746002,-0.3601679503917694,0.30109691619873047,0.3892854154109955,-0.2802964150905609,0.1400589644908905,0.3984168767929077,-0.19002702832221985,-0.056741103529930115,-0.31512919068336487,0.40480902791023254,-0.19832001626491547,-0.23624716699123383,-0.2974070608615875,0.0471753366291523,-0.2773614227771759,0.3669983744621277,0.1806308776140213,-0.16606296598911285,-0.10672180354595184,-0.09532979875802994,-0.33842259645462036,-0.4229055345058441,-0.03428763151168823,0.09398986399173737,0.3806152641773224,0.30408012866973877,-0.32760152220726013,0.40690916776657104,0.34122949838638306,0.36092472076416016,0.2148539274930954,0.2062685340642929,0.04776989668607712,0.22700703144073486,-0.07
0.18135136365890503,-0.16552789509296417,-0.10835619270801544,-0.09419532865285873,-0.3395439386367798,-0.42219600081443787,-0.03235870599746704,0.09307999908924103,0.3811723589897156,0.30272331833839417,-0.32720500230789185,0.4058791399002075,0.341264009475708,0.3511687219142914,0.21262529492378235,0.21261464059352875,0.05020087957382202,0.22446775436401367,-0.0706537663936615,0.2478111982345581,-0.10016991198062897,-0.33856311440467834,0.4768922030925751,0.12727166712284088,0.3671026825904846,0.04951862618327141,0.22890254855155945,0.3741447925567627,0.4197167754173279,-0.039606973528862,0.40363073348999023,0.34005817770957947,0.18644969165325165,-0.09369061142206192,-0.27770406007766724,0.05408051609992981,0.33558207750320435,-0.14650672674179077,0.17978030443191528,0.4034388065338135,0.37778037786483765,0.3918904662132263,-0.04517524316906929,0.10714973509311676,0.4795709252357483,-0.2181772142648697,-0.30387765169143677,-0.040635623037815094,0.10640145093202591,0.32496100664138794,-0.20422089099884033,0.3706582188606262,0.17643499374389648,-0.4077600836753845,-0.27970072627067566,0.1826653629541397,-0.15407302975654602,0.25471293926239014,-0.2095036506652832,0.4795709252357483,0.45061221718788147,0.35902905464172363,0.09664861112833023,-0.05172601342201233,0.18708401918411255,-0.192901149392128,0.40627092123031616,0.4665130376815796,0.4671992063522339,0.34906813502311707,-0.0786694884300232,-0.47729170322418213,-0.08601056039333344,-0.24979498982429504,-0.04739218205213547,-0.4033825397491455,-0.44051820039749146,-0.3437308669090271,0.21044164896011353,-0.3976830840110779,0.11302836239337921,-0.05016608536243439,0.3842405080795288,-0.4665147662162781,0.06321105360984802,0.4795709252357483,0.4297690987586975,-0.3142102062702179,-0.07679954916238785,-0.03635197505354881,-0.20384658873081207,0.3774593472480774,-0.08306422829627991,-0.2545665502548218,0.021596983075141907,-0.12906664609909058,0.25460824370384216,-0.27531594038009644,0.3853684067726135,-0.38894590735435486,-0.04985114932060242,0.14397214353084564,0.09803947806358337,-0.22850564122200012,-0.2154632806777954,-0.005522141233086586,0.3696839213371277,-0.19238591194152832,0.37104085087776184,-0.31811660528182983,-0.2413756400346756,0.32104313373565674,-0.08751942217350006,0.2513 ...

# %%
path = os.path.join(parent_dir, 'data/IFGM/DGCNN')
all_adv_pc = run(True, 'adv_test_target', path, 'dgcnn', signed = False)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 3/64 successful attacks in iteration  6
# 3/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 0/64 successful attacks in iteration  9
# 0/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 0/64 successful attacks in iteration  9
# 0/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 0/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 0/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 0/64 successful attacks in iteration  9
# 0/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 2/64 successful attacks in iteration  3
# 2/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 2/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 3/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 5/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 4/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 2/64 successful attacks in iteration  9
# 2/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 0/64 successful attacks in iteration  1
# 0/64 successful attacks in iteration  2
# 0/64 successful attacks in iteration  3
# 0/64 successful attacks in iteration  4
# 0/64 successful attacks in iteration  5
# 0/64 successful attacks in iteration  6
# 0/64 successful attacks in iteration  7
# 0/64 successful attacks in iteration  8
# 0/64 successful attacks in iteration  9
# 0/64 Total successful attacks
#
# 1/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 1/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 1/64 successful attacks in iteration  7
# 1/64 successful attacks in iteration  8
# 1/64 successful attacks in iteration  9
# 1/64 Total successful attacks
#
# 0/64 successful attacks in iteration  0
# 1/64 successful attacks in iteration  1
# 1/64 successful attacks in iteration  2
# 1/64 successful attacks in iteration  3
# 1/64 successful attacks in iteration  4
# 2/64 successful attacks in iteration  5
# 1/64 successful attacks in iteration  6
# 2/64 successful attacks in iteration  7
# 2/64 successful attacks in iteration  8
# 3/64 successful attacks in iteration  9
# 3/64 Total successful attacks
#
# 0/36 successful attacks in iteration  0
# 0/36 successful attacks in iteration  1
# 0/36 successful attacks in iteration  2
# 0/36 successful attacks in iteration  3
# 0/36 successful attacks in iteration  4
# 0/36 successful attacks in iteration  5
# 0/36 successful attacks in iteration  6
# 0/36 successful attacks in iteration  7
# 0/36 successful attacks in iteration  8
# 0/36 successful attacks in iteration  9
# 0/36 Total successful attacks
#
# Success Rate: 0.02633711507293355

# %%
x1, y1, z1 = all_adv_pc[4].T
x2, y2, z2 = test_X[4].T
pcshow(x1, y1, z1, color='red')
pcshow(x2, y2, z2, color='red')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="246a7fd5-05a2-4a2d-8dc9-018eff4f0de3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("246a7fd5-05a2-4a2d-8dc9-018eff4f0de3")) {                    Plotly.newPlot(                        "246a7fd5-05a2-4a2d-8dc9-018eff4f0de3",                        [{"mode":"markers","x":[-0.21817262470722198,0.17048101127147675,-0.25179290771484375,-0.10839827358722687,-0.09269668906927109,-0.21804796159267426,-0.3768424689769745,0.31467869877815247,0.33612459897994995,-0.40834805369377136,-0.22861503064632416,-0.355573832988739,0.1363368183374405,0.3862636685371399,0.0033722086809575558,-0.017670711502432823,-0.18895484507083893,0.05117875337600708,0.013984429650008678,-0.07840144634246826,0.2649252414703369,-0.03931163251399994,0.16239699721336365,-0.3697863519191742,-0.11924540996551514,-0.07738897949457